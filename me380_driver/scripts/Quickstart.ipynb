# %% [markdown]
# # IKpy Quickstart #

# %% [markdown]
# # Requirements

# %% [markdown]
# First, you need to install IKPy (see [installations instructions](https://github.com/Phylliade/ikpy)).
# You also need a URDF file.
# By default, we use the files provided in the [resources](https://github.com/Phylliade/ikpy/tree/master/resources) folder of the IKPy repo.

# %% [markdown]
# Import the IKPy module :

# %%
import ikpy.chain
import numpy as np
import ikpy.utils.plot as plot_utils

# %% [markdown]
# The basic element of IKPy is the kinematic `Chain`.
# To create a chain from an URDF file :

# %%
my_chain = ikpy.chain.Chain.from_urdf_file("../urdf/me380_robot.urdf", active_links_mask=[False, True, True, True, True, True, True])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 my_chain = ikpy.chain.Chain.from_urdf_file("../urdf/me380_robot.urdf")
#
# File ~/miniforge3/lib/python3.12/site-packages/ikpy/chain.py:324, in Chain.from_urdf_file(cls, urdf_file, base_elements, last_link_vector, base_element_type, active_links_mask, name, symbolic)
#     321 if base_elements is None:
#     322     base_elements = ["base_link"]
# --> 324 links = URDF.get_urdf_parameters(urdf_file, base_elements=base_elements, last_link_vector=last_link_vector, base_element_type=base_element_type, symbolic=symbolic)
#     325 # Add an origin link at the beginning
#     326 chain = cls([link_lib.OriginLink()] + links, active_links_mask=active_links_mask, name=name, urdf_metadata=urdf_metadata)
#
# File ~/miniforge3/lib/python3.12/site-packages/ikpy/urdf/URDF.py:272, in get_urdf_parameters(urdf_file, base_elements, last_link_vector, base_element_type, symbolic)
#     269         if "upper" in limit.attrib:
#     270             bounds[1] = float(limit.attrib["upper"])
# --> 272     parameters.append(lib_link.URDFLink(
#     273         name=joint.attrib["name"],
#     274         bounds=tuple(bounds),
#     275         origin_translation=origin_translation,
#     276         origin_orientation=origin_orientation,
#     277         rotation=rotation,
#     278         translation=translation,
#     279         use_symbolic_matrix=symbolic,
#     280         joint_type=joint_type
#     281     ))
#     283 # Add last_link_vector to parameters
#     284 if last_link_vector is not None:
#     285     # The last link doesn't provide a rotation
#
# File ~/miniforge3/lib/python3.12/site-packages/ikpy/link.py:158, in URDFLink.__init__(self, name, origin_translation, origin_orientation, rotation, translation, bounds, angle_representation, use_symbolic_matrix, joint_type)
#     156 theta = sympy.symbols("theta")
#     157 mu = sympy.symbols("mu")
# --> 158 self.symbolic_transformation_matrix = self._apply_geometric_transformations(theta=theta, mu=mu, symbolic=True)
#
# File ~/miniforge3/lib/python3.12/site-packages/ikpy/link.py:219, in URDFLink._apply_geometric_transformations(self, theta, mu, symbolic)
#     216 symbolic_frame_matrix = np.eye(4)
#     218 # Apply translation matrix
# --> 219 symbolic_frame_matrix = symbolic_frame_matrix * sympy.Matrix(geometry.homogeneous_translation_matrix(*self.origin_translation))
#     221 # Apply orientation matrix
#     222 symbolic_frame_matrix = symbolic_frame_matrix * geometry.cartesian_to_homogeneous(geometry.rpy_matrix(*self.origin_orientation))
#
# TypeError: homogeneous_translation_matrix() missing 1 required positional argument: 'trans_z'

# %% [markdown]
# Note : as mentioned before, here we use a file in the resource folder.

# %% [markdown]
# # Inverse kinematics

# %% [markdown]
# In Inverse Kinematics, you want your kinematic chain to reach a 3D position in space.

# %% [markdown]
# To have a more general representation of position, IKPy works with homogeneous coordinates. It is a 4x4 matrix storing both position and orientation.
# Prepare your desired position as a 4x4 matrix. Here we only consider position, not orientation of the chain.

# %%
target_position = [ 0.1, -0.2, 0.1]

# %%
print("The angles of each joints are : ", my_chain.inverse_kinematics(target_position))
# Out:
# The angles of each joints are :  [ 0.          0.77375199 -1.26611195  0.32302683 -0.75260337  1.03033305
#   0.        ]

# %% [markdown]
# You can check that the Inverse Kinematics is correct by comparing with the original position vector :

# %%
real_frame = my_chain.forward_kinematics(my_chain.inverse_kinematics(target_position))
print("Computed position vector : %s, original position vector : %s" % (real_frame[:3, 3], target_position))
# Out:
# Computed position vector : [ 0.0999999  -0.1999999   0.09999988], original position vector : [0.1, -0.2, 0.1]

# %% [markdown]
# # Plotting
# And finally plot the result :

# %% [markdown]
# (If the code below doesn't work, comment the `%maplotlib widget` line, and uncomment the `%matplotlib inline` line)

# %%
# Optional: support for 3D plotting in the NB
# If there is a matplotlib error, uncomment the next line, and comment the line below it.
# %matplotlib inline
# %matplotlib widget
import matplotlib.pyplot as plt
fig, ax = plot_utils.init_3d_figure()
my_chain.plot(my_chain.inverse_kinematics(target_position), ax, target=target_position)
plt.xlim(-0.1, 0.1)
plt.ylim(-0.1, 0.1)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# (-0.1, 0.1)

# %% [markdown]
# You're done! Go to the [tutorials](https://github.com/Phylliade/ikpy/blob/master/tutorials/ikpy/getting_started.md) to understand the general concepts of the library.
